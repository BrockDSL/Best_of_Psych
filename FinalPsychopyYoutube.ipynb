# %% [markdown]
# ![DSL_logo](https://github.com/BrockDSL/Intro_to_Python_Workshop/blob/master/dsl_logo.png?raw=1)
#
# ![PythonPsycology](http://www.pygaze.org/wp-content/uploads/2016/10/Dalmaijer_2016_PEP-1024x356.jpg)
#
# # Welcome to Python for Psycholgy Part 4!
#
# By the end of today we'll know all about the following;
#
# - Create psychology experiments for participants to take using Psychopy
# - Psychopy is a platform made using Python code. However, you do not need to look at the Python script if you don't want to. However, it is a good idea to look the script over once you've finished creating the experiment in the userface.

# %% [markdown]
# The purpose of this tutorial is to allow you to learn how to use Psychopy at your own pace by watching the embedded Youtube videos.

# %% [markdown]
# Go to this link to download the standalone version of Psychopy compatible with your computer
#
#
#
# [![image.png](data:image/png;base64,...)](https://www.psychopy.org/download.html)

# %% [markdown]
# **Step 1** Insert a routine called exposure

# %% [markdown]
# Watch the video below to see how to insert the exposure routine.

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('lTL5uwbelBg')

# %% [markdown]
# Here are screenshots of what your dialog boxes should say at the end of step 1

# %% [markdown]
# Name the new Routine 'exposure'. Click ok
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click the text icon ![image.png](data:image/png;base64,...), and enter the following in the text box
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 2** Insert new routine, called instructions

# %% [markdown]
# Watch the video below to see how to insert the instructions routine

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('qQdtaTdxM4w')

# %% [markdown]
# Here are screenshots of what the dialog boxes should say for step 2

# %% [markdown]
# Insert new routine, call it instructions
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 3** Add text for the instructions tab

# %% [markdown]
# Watch the video below to see how to add the text for the instructions tab

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('amlU2lzMLig')

# %% [markdown]
# Ensure that your text dialogue box says the following after step 3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 4** Insert keyboard response icon

# %% [markdown]
# Watch the video below to see how to insert a keyboard response

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('nXFmaSnzXk8')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/nXFmaSnzXk8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Ensure that the keyboard dialog box says the following after step 4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 5** add text to test tab

# %% [markdown]
# Watch the video below to see how to add text to the test tab

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('f0drYGMYmQA')

# %% [markdown]
# Ensure that the text popup box says the following for step 5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 6** Insert a loop

# %% [markdown]
# Watch the video below to see how to insert a loop

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('_Tthgxa_220')

# %% [markdown]
# Insert a loop, ensuring the loop popup dialog box says the following for step 6
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 7** Insert new routine called test_instructions

# %% [markdown]
# Watch the video below to see how to insert a new routine called test_instructions

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('2KqAYsYWcGo')

# %% [markdown]
# Inserting new routine called test_instructions for step 7
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 8** Insert Keybord for test_instructions tab

# %% [markdown]
# Watch the video below to see how to insert a keyboard response for the test_instructions tab

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('y92SVSr7PpM')

# %% [markdown]
# Ensure the following dialog box for step 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step9** Insert optional Thanks routine

# %% [markdown]
# Watch video to see how to insert an optional thanks text that shows at the end of the experiment.

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('SMeQY10567c')

# %% [markdown]
# Ensure the textbox for the thanks routine says the following for step 9
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 10** Hit the green play button ![image.png](data:image/png;base64,...), and test your experiment!
#
# You will need to enter your name in when the experiment launches

# %% [markdown]
# ##Additional actions
#
# Click the settings ![image.png](data:image/png;base64,...) icon to select the format you want the data to be collected in.
#
# Click the python symbol ![image.png](data:image/png;base64,...) to view the python code that created your experiment!
